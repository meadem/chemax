# %%
import chempy
from chempy import load

# %%
CV = load.files(18, file='101822_', folder='data/Data Import data', step=1)

# %%
CV[1].dtypes
# Out:
# mode                 int64
# ox/red               int64
# error                int64
# control changes      int64
# counter inc.         int64
# time/s             float64
# control/V          float64
# Ewe/V              float64
# <I>/mA             float64
# cycle number       float64
# (Q-Qo)/C           float64
# I Range              int64
# P/W                float64
# Unnamed: 13        float64
# dtype: object

# %%
print(CV[1]['Ewe/V'])
# Out:
# 0       -0.588510
# 1       -0.588514
# 2       -0.588488
# 3       -0.588431
# 4       -0.588350
#            ...
# 11430   -0.631369
# 11431   -0.630364
# 11432   -0.629696
# 11433   -0.629495
# 11434   -0.629437
# Name: Ewe/V, Length: 11435, dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

data_directory = 'data'
data_file = 'ROSS_data_20201010.csv'
file = os.path.join(data_directory, data_file)
experiment1 = pd.read_csv(file, delimiter=',')

# %%
print(experiment1)
# Out:
#             Date      time  lab_temperature  reactor_temperature  current  \
# 0     10/10/2020   7:42:06            15.69                15.77     4.39
# 1     10/10/2020   7:42:18            15.73                15.75     4.64
# 2     10/10/2020   7:42:43            15.73                15.71     3.68
# 3     10/10/2020   7:42:57            15.75                15.77     3.84
# 4     10/10/2020   7:43:12            15.77                15.75     4.59
# ...          ...       ...              ...                  ...      ...
# 2967  10/10/2020  17:35:26            18.45                22.05     2.67
# 2968  10/10/2020  17:35:38            18.45                22.07     1.71
# 2969  10/10/2020  17:35:54            18.43                21.95     1.92
# 2970  10/10/2020  17:36:05            18.45                21.95     1.81
# 2971  10/10/2020  17:36:17            18.43                22.07     1.92
#
#       voltage   power
# 0       27.18  119.31
# 1       26.93  125.03
# 2       26.97   99.35
# 3       26.95  103.36
# 4       26.96  123.82
# ...       ...     ...
# 2967    27.90   74.58
# 2968    27.87   47.76
# 2969    27.88   53.41
# 2970    27.87   50.59
# 2971    27.86   53.38
#
# [2972 rows x 7 columns]

# %%
# Define figure and two subplots
fig1 = plt.figure(1, figsize=(14,7))
ax1 = fig1.add_subplot(1,1,1)

# Plot data traces for subplots
ax1.plot(experiment1['time'], experiment1['voltage'], linewidth = 3, label = 'no label rn')

# Set subplot axis labels
ax1.set_xlabel(r'$Time \: (?)$', fontsize = 16)
ax1.set_ylabel(r'$Voltage \: (V)$', fontsize = 16)

# can't remember how to do this: ax1.set_xlimit(20)

# Make subplot axes visible (add reference lines)
ax1.axhline(y=0, color='k')
ax1.axvline(x=0, color='k')

# Show legends for subplots
ax1.legend(loc='lower right')

# Caption figure
caption1 = " "
fig1.text(0.1, -0.08, caption1, fontsize=14, va='bottom', ha='left', wrap=True)
# Out:
# Text(0.1, -0.08, ' ')

# %% [markdown]
# https://joss.theoj.org/papers/10.21105/joss.00676.pdf

# %%
# Amphlett_Test

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

data_directory = 'data'
data_file = 'Amphlett_Test.csv'
file = os.path.join(data_directory, data_file)
experiment2 = pd.read_csv(file, delimiter=',')

# %%
print(experiment2)
# Out:
#      I (A)  Enernst (V)  Eta Activation (V)  Eta Concentration (V)  \
# 0      0.0      1.19075            0.000000               0.000000
# 1      0.1      1.19075            0.118071               0.000019
# 2      0.2      1.19075            0.163976               0.000039
# 3      0.3      1.19075            0.190830               0.000059
# 4      0.4      1.19075            0.209882               0.000078
# ..     ...          ...                 ...                    ...
# 745   74.5      1.19075            0.556062               0.059037
# 746   74.6      1.19075            0.556150               0.060133
# 747   74.7      1.19075            0.556239               0.061316
# 748   74.8      1.19075            0.556328               0.062603
# 749   74.9      1.19075            0.556416               0.064012
#
#      Eta Ohmic (V)  Loss (V)  PEM Efficiency ()  Power (W)  Power-Stack (W)  \
# 0         0.000000  0.000000           0.763301   0.000000         0.000000
# 1         0.000175  0.118265           0.687490   0.107248         0.107248
# 2         0.000351  0.164366           0.657938   0.205277         0.205277
# 3         0.000526  0.191414           0.640600   0.299801         0.299801
# 4         0.000701  0.210662           0.628262   0.392035         0.392035
# ..             ...       ...                ...        ...              ...
# 745       0.203781  0.818880           0.238378  27.704314        27.704314
# 746       0.204246  0.820530           0.237321  27.618442        27.618442
# 747       0.204712  0.822268           0.236207  27.525629        27.525629
# 748       0.205179  0.824110           0.235026  27.424705        27.424705
# 749       0.205647  0.826075           0.233766  27.314165        27.314165
#
#      Power-Thermal (W)  VStack (V)  Vcell (V)
# 0             0.000000    1.190750   1.190750
# 1             0.015752    1.072485   1.072485
# 2             0.040723    1.026384   1.026384
# 3             0.069199    0.999336   0.999336
# 4             0.099965    0.980088   0.980088
# ..                 ...         ...        ...
# 745          63.930686    0.371870   0.371870
# 746          64.139558    0.370220   0.370220
# 747          64.355371    0.368482   0.368482
# 748          64.579295    0.366640   0.366640
# 749          64.812835    0.364675   0.364675
#
# [750 rows x 12 columns]

# %%
# Define figure and two subplots
fig2 = plt.figure(2, figsize=(14,7))
ax1 = fig2.add_subplot(1,1,1)

# Plot data traces for subplots
# ax1.plot(np.arange(0,750*5,5), experiment2['VStack (V)'], linewidth = 3, label = 'no label rn')
ax1.plot(experiment2['I (A)'], experiment2['VStack (V)'], linewidth = 3, label = 'no label rn')

# Set subplot axis labels
ax1.set_xlabel(r'$Current \: (A)$', fontsize = 16)
ax1.set_ylabel(r'$Voltage \: (V)$', fontsize = 16)

# can't remember how to do this: ax1.set_xlimit(20)

# Make subplot axes visible (add reference lines)
ax1.axhline(y=0, color='k')
ax1.axvline(x=0, color='k')

# Show legends for subplots
ax1.legend(loc='lower right')

# Caption figure
caption1 = " "
fig1.text(0.1, -0.08, caption1, fontsize=14, va='bottom', ha='left', wrap=True)
# Out:
# Text(0.1, -0.08, ' ')

# %%
# Chamberline_Test

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

data_directory = 'OPEM\Chamberline-Kim'
data_file = 'Chamberline_Test.csv'
file = os.path.join(data_directory, data_file)
chamberline = pd.read_csv(file, delimiter=',')

# %%
print(chamberline)
# Out:
#      I (A)  PEM Efficiency ()  Power (W)  Power-Stack (W)  Power-Thermal (W)  \
# 0      1.0           0.797966   1.244827         1.244827          -0.014827
# 1      1.1           0.793334   1.361362         1.361362          -0.008362
# 2      1.2           0.789069   1.477137         1.477137          -0.001137
# 3      1.3           0.785111   1.592206         1.592206           0.006794
# 4      1.4           0.781416   1.706612         1.706612           0.015388
# ..     ...                ...        ...              ...                ...
# 410   42.0           0.236073  15.467509        15.467509          36.192491
# 411   42.1           0.231264  15.188505        15.188505          36.594495
# 412   42.2           0.226374  14.902637        14.902637          37.003363
# 413   42.3           0.221400  14.609763        14.609763          37.419237
# 414   42.4           0.216342  14.309740        14.309740          37.842260
#
#      VStack (V)  Vcell (V)
# 0      1.244827   1.244827
# 1      1.237602   1.237602
# 2      1.230948   1.230948
# 3      1.224774   1.224774
# 4      1.219009   1.219009
# ..          ...        ...
# 410    0.368274   0.368274
# 411    0.360772   0.360772
# 412    0.353143   0.353143
# 413    0.345384   0.345384
# 414    0.337494   0.337494
#
# [415 rows x 7 columns]

# %%
# Define figure and two subplots
fig3 = plt.figure(3, figsize=(14,7))
ax1 = fig3.add_subplot(1,1,1)

# Plot data traces for subplots
ax1.plot(chamberline['I (A)'], chamberline['VStack (V)'], linewidth = 3, label = 'no label rn')

# Set subplot axis labels
ax1.set_xlabel(r'$Current \: (A)$', fontsize = 16)
ax1.set_ylabel(r'$Voltage \: (V)$', fontsize = 16)

# can't remember how to do this: ax1.set_xlimit(20)

# Make subplot axes visible (add reference lines)
ax1.axhline(y=0, color='k')
ax1.axvline(x=0, color='k')

# Show legends for subplots
ax1.legend(loc='lower right')

# Caption figure
caption1 = " "
fig1.text(0.1, -0.08, caption1, fontsize=14, va='bottom', ha='left', wrap=True)
# Out:
# Text(0.1, -0.08, ' ')

# %%
# Larminie-Dicks_Test

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

data_directory = 'OPEM\Larminie-Dicks'
data_file = 'Larminiee_Test.csv'
file = os.path.join(data_directory, data_file)
larminiee = pd.read_csv(file, delimiter=',')

# %%
print(larminiee)
# Out:
#      I (A)  PEM Efficiency ()  Power (W)  Power-Stack (W)  Power-Thermal (W)  \
# 0      0.1           0.603904   0.094209         2.166807           0.662193
# 1      0.2           0.593599   0.185203         4.259665           1.398335
# 2      0.3           0.585432   0.273982         6.301594           2.185406
# 3      0.4           0.578660   0.361084         8.304929           3.011071
# 4      0.5           0.572869   0.446838        10.277274           3.867726
# ..     ...                ...        ...              ...                ...
# 974   97.5           0.238361  36.254666       833.857320        1924.417680
# 975   97.6           0.237798  36.206122       832.740810        1928.363190
# 976   97.7           0.237215  36.154472       831.552858        1932.380142
# 977   97.8           0.236612  36.099416       830.286557        1936.475443
# 978   97.9           0.235985  36.040605       828.933926        1940.657074
#
#      VStack (V)  Vcell (V)
# 0     21.668068   0.942090
# 1     21.298326   0.926014
# 2     21.005313   0.913274
# 3     20.762323   0.902710
# 4     20.554547   0.893676
# ..          ...        ...
# 974    8.552383   0.371843
# 975    8.532180   0.370964
# 976    8.511288   0.370056
# 977    8.489638   0.369115
# 978    8.467149   0.368137
#
# [979 rows x 7 columns]

# %%
# Define figure and two subplots
fig4 = plt.figure(4, figsize=(14,7))
ax1 = fig4.add_subplot(1,1,1)

# Plot data traces for subplots
ax1.plot(larminiee['I (A)'], larminiee['VStack (V)'], linewidth = 3, label = 'no label rn')

# Set subplot axis labels
ax1.set_xlabel(r'$Current \: (A)$', fontsize = 16)
ax1.set_ylabel(r'$Voltage \: (V)$', fontsize = 16)

# can't remember how to do this: ax1.set_xlimit(20)

# Make subplot axes visible (add reference lines)
ax1.axhline(y=0, color='k')
ax1.axvline(x=0, color='k')

# Show legends for subplots
ax1.legend(loc='lower right')

# Caption figure
caption1 = " "
fig1.text(0.1, -0.08, caption1, fontsize=14, va='bottom', ha='left', wrap=True)
# Out:
# Text(0.1, -0.08, ' ')

# %%
# Need to functionalize my plotting
# If this is the standard, then what do I need to do?
'''
# Define figure and two subplots
fig4 = plt.figure(4, figsize=(14,7))
ax1 = fig4.add_subplot(1,1,1)

# Plot data traces for subplots
ax1.plot(larminiee['I (A)'], larminiee['VStack (V)'], linewidth = 3, label = 'no label rn')

# Set subplot axis labels
ax1.set_xlabel(r'$Current \: (A)$', fontsize = 16)
ax1.set_ylabel(r'$Voltage \: (V)$', fontsize = 16)

# can't remember how to do this: ax1.set_xlimit(20)

# Make subplot axes visible (add reference lines)
ax1.axhline(y=0, color='k')
ax1.axvline(x=0, color='k')

# Show legends for subplots
ax1.legend(loc='lower right')

# Caption figure
caption1 = " "
fig1.text(0.1, -0.08, caption1, fontsize=14, va='bottom', ha='left', wrap=True)
'''
# Out:
# '\n# Define figure and two subplots\nfig4 = plt.figure(4, figsize=(14,7))\nax1 = fig4.add_subplot(1,1,1)\n\n# Plot data traces for subplots\nax1.plot(larminiee[\'I (A)\'], larminiee[\'VStack (V)\'], linewidth = 3, label = \'no label rn\')\n\n# Set subplot axis labels\nax1.set_xlabel(r\'$Current \\: (A)$\', fontsize = 16)\nax1.set_ylabel(r\'$Voltage \\: (V)$\', fontsize = 16)\n\n# can\'t remember how to do this: ax1.set_xlimit(20)\n\n# Make subplot axes visible (add reference lines)\nax1.axhline(y=0, color=\'k\')\nax1.axvline(x=0, color=\'k\')\n\n# Show legends for subplots\nax1.legend(loc=\'lower right\')\n\n# Caption figure\ncaption1 = " "\nfig1.text(0.1, -0.08, caption1, fontsize=14, va=\'bottom\', ha=\'left\', wrap=True)\n'

# %%
def plot(figure_id, data_array, x_column, y_column, x_label="", y_label="", caption="", show_axes=True):
    
    import matplotlib.pyplot as plt
    
    figure = plt.figure(figure_id, figsize=(14,7))
    
    axis = figure.add_subplot(1,1,1)
    
    axis.plot(data_array[x_column], data_array[y_column], linewidth = 3)
    
    axis.set_xlabel(x_label, fontsize = 16)
    axis.set_ylabel(y_label, fontsize = 16)

    if show_axes:
        axis.axhline(y=0, color='k')
        axis.axvline(x=0, color='k')

    figure.text(0.1, -0.08, caption, fontsize=14, va='bottom', ha='left', wrap=True)

# %%
plot(5, larminiee, 'I (A)', "Current (A)", 'VStack (V)', "Stack Voltage (V)", "OPEM Larminie-Dicks test with standard model parameters")

# %%
import chempy.load as load

chakraborty = load.files(1, file='Chakraborty_Test.csv', folder='OPEM/Chakraborty')

# load function needs to be redone so it doesn't specify .txt
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36240\4162936874.py in <module>
#       1 import chempy.load as load
#       2
# ----> 3 chakraborty = load.files(1, file='Chakraborty_Test.csv', folder='OPEM/Chakraborty')
#
# ~\sidewinder\chempy\load.py in files(num, file, folder, step)
#      56         file_name = file + str(file_number) + '.txt'
#      57         file_path = os.path.join(folder, file_name)
# ---> 58         dictionary[file_number] = pd.read_csv(file_path, delimiter='\t', encoding='unicode_escape')
#      59     return dictionary
#      60
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'OPEM/Chakraborty\\Chakraborty_Test.csv1.txt'

# %%
data_directory = 'OPEM/Chakraborty'
data_file = 'Chakraborty_Test.csv'
file = os.path.join(data_directory, data_file)
chakraborty = pd.read_csv(file, delimiter=',')

# %%
print(chakraborty)
# Out:
#       I (A)     E (V)  FC Efficiency ()  FC Power (W)  FC Voltage (V)  \
# 0       0.1  1.172953          0.598908      0.110948        1.109476
# 1       0.2  1.153943          0.598730      0.221830        1.109148
# 2       0.3  1.142823          0.598553      0.332646        1.108820
# 3       0.4  1.134934          0.598376      0.443397        1.108492
# 4       0.5  1.128814          0.598199      0.554082        1.108164
# ...     ...       ...               ...           ...             ...
# 2994  299.5  0.953424          0.068594     38.057460        0.127070
# 2995  299.6  0.953415          0.068417     37.971860        0.126742
# 2996  299.7  0.953406          0.068240     37.886196        0.126414
# 2997  299.8  0.953397          0.068062     37.800465        0.126086
# 2998  299.9  0.953388          0.067885     37.714669        0.125757
#
#       Nernst Gain (V)  Ohmic Loss (V)     PH2 (atm)  PH2O (atm)     PO2 (atm)  \
# 0           -0.063148        0.000328  1.536825e-07    0.000002  1.216789e-07
# 1           -0.044139        0.000656  3.073650e-07    0.000004  2.433578e-07
# 2           -0.033019        0.000984  4.610475e-07    0.000006  3.650367e-07
# 3           -0.025129        0.001313  6.147300e-07    0.000007  4.867156e-07
# 4           -0.019009        0.001641  7.684125e-07    0.000009  6.083945e-07
# ...               ...             ...           ...         ...           ...
# 2994         0.156380        0.982734  4.602791e-04    0.005523  3.644283e-04
# 2995         0.156389        0.983062  4.604328e-04    0.005525  3.645500e-04
# 2996         0.156398        0.983391  4.605865e-04    0.005527  3.646717e-04
# 2997         0.156407        0.983719  4.607402e-04    0.005529  3.647933e-04
# 2998         0.156416        0.984047  4.608938e-04    0.005531  3.649150e-04
#
#       Power-Thermal (W)
# 0              0.012052
# 1              0.024170
# 2              0.036354
# 3              0.048603
# 4              0.060918
# ...                 ...
# 2994         330.327540
# 2995         330.536140
# 2996         330.744804
# 2997         330.953535
# 2998         331.162331
#
# [2999 rows x 11 columns]

# %%
plot(6, chakraborty, 'I (A)', 'FC Voltage (V)', 'Current (A)', "FC Voltage (V)", "OPEM Chakraborty test with standard model parameters")

# %% [markdown]
# # try to simulate electrolyzer running?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import chempy as cp

class simulator:
    '''
    Needs:
        - noise
        - input voltage and FY decay rates to get outputs
    
    resolution in seconds
    conditioning dict entries are current:duration (current in A; duration in minutes)
    current (after conditioning program) is in A
    runtime (after conditioning program) is in hours
    area is the electrode area in m2
    
    '''
    
    def __init__(self, resolution=60, conditioning={0.1:60, 1:60, 10:60}, current=30, area=0.1, SNR=99):
        continue
    
    def calculateVoltage():
        continue
    
    def calculateEfficiency():
        continue
    
    def calculateFY():
        continue
    
    def calculateUtilization():
        continue
# Out:
#   File "C:\Users\maxtm\AppData\Local\Temp\ipykernel_10452\678981694.py", line 21
#     continue
#     ^
# SyntaxError: 'continue' not properly in loop

# %% [markdown]
# # Income Comparison module

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
To add:
 - social security deduction?
 - print method for exporting calculated values and saving them

"""


class income_comparison():
    
    def __init__(self, offer, state, COL_difference, 
                 current_income, current_state, 
                 fixed_expenses, current_flex_expenses):
        
        
        self.COL_difference = COL_difference
        self.fixed_expenses = fixed_expenses
        self.current_flex_expenses = current_flex_expenses
        self.current_expenses = fixed_expenses + current_flex_expenses
        self.prospective_expenses = self.COL_adjusted_expenses()
        
        # Calculate current AIF
        self.calculate_adjusted_income_factor(current_income, "CA", current=True)
        
        # Calculate prospective AIF
        self.calculate_adjusted_income_factor(offer, state)
    
    
    def calculate_adjusted_income_factor(self, income, state, current=False):
        
        if current:
            federal_tax_burden = self.federal_tax_burden(income, status="single")
            state_tax_burden = self.state_tax_burden(income, state=state, status="single")
            tax_burden = self.tax_burden(federal_tax_burden, state_tax_burden)
            tax_adjusted_income = self.tax_adjusted_offer(income, tax_burden)
            current_AIF = self.adjusted_income_factor(tax_adjusted_income, self.current_expenses)
        
            self.current_federal_tax_burden = federal_tax_burden
            self.current_state_tax_burden = state_tax_burden
            self.current_tax_burden = tax_burden
            self.current_tax_adjusted_income = tax_adjusted_income
            self.current_AIF = current_AIF
        
        else:
            federal_tax_burden = self.federal_tax_burden(income, status="single")
            state_tax_burden = self.state_tax_burden(income, state=state, status="single")
            tax_burden = self.tax_burden(federal_tax_burden, state_tax_burden)
            tax_adjusted_income = self.tax_adjusted_offer(income, tax_burden)
            AIF = self.adjusted_income_factor(tax_adjusted_income, self.prospective_expenses)
        
            self.prospective_federal_tax_burden = federal_tax_burden
            self.prospective_state_tax_burden = state_tax_burden
            self.prospective_tax_burden = tax_burden
            self.prospective_tax_adjusted_income = tax_adjusted_income
            self.prospective_AIF = AIF
    
    
    def adjusted_income_factor(self, tax_adjusted_offer, COL_adjusted_expenses):
        result = tax_adjusted_offer / COL_adjusted_expenses
        return result


    def tax_adjusted_offer(self, offer, tax_burden):
        result = offer - tax_burden
        self.adjusted_offer = result
        return result


    def tax_burden(self, federal_tax_burden, state_tax_burden):
        result = federal_tax_burden + state_tax_burden
        self.tax_burden
        return result


    def federal_tax_burden(self, income, status="single"):
        """
        For 2025. Does not provide accuracte values for incomes of $1,000,000+.
        """

        result = 0.0

        brackets = {
                    1:[0,11926,0.10],
                    2:[11926,48476,0.12],
                    3:[48476,103351,0.22],
                    4:[103351,197301,0.24],
                    5:[197301,250526,0.32],
                    6:[250526,626351,0.35],
                    7:[626351,1e6,0.37]
        }

        if status == "single":

            for bracket in brackets.values():

                lower_bracket_boundary = bracket[0]
                upper_bracket_boundary = bracket[1]
                bracket_rate = bracket[2]

                if income >= upper_bracket_boundary:
                    result += bracket_rate * ( upper_bracket_boundary - lower_bracket_boundary )

                elif income < upper_bracket_boundary:
                    result += bracket_rate * ( income - lower_bracket_boundary )
                    break

                else:
                    raise ValueError("Something went wrong...")

        else:
            raise NameError("Filing status '" + status + "' was not found. Only 'single' is enabled at this time.")

        return result


    def state_tax_burden(self, income, state="CA", status="single"):
        """
        For 2025. Does not provide accuracte values for incomes of $1,000,000+.
        """

        result = 0.0

        brackets = {
                    "CA":{
                          1:[0,10757,0.01],
                          2:[10757,25500,0.02],
                          3:[25500,40246,0.04],
                          4:[40246,55867,0.06],
                          5:[55867,70607,0.08],
                          6:[70607,360660,0.093],
                          7:[360660,432788,0.103],
                          8:[432788,721315,0.113],
                          9:[721315,1e6,0.123]
                        },
                    "CT":{
                          1:[0,10000,0.02],
                          2:[10000,50000,0.045],
                          3:[50000,100000,0.055],
                          4:[100000,200000,0.06],
                          5:[200000,250000,0.065],
                          6:[250000,500000,0.069],
                          7:[500000,1e6,0.0699]
                        }
        }

        if status == "single":

            for state_ in brackets.keys():

                try:
                    if state_ == state:
                        for bracket in brackets[state].values():

                            lower_bracket_boundary = bracket[0]
                            upper_bracket_boundary = bracket[1]
                            bracket_rate = bracket[2]

                            if income >= upper_bracket_boundary:
                                result += bracket_rate * ( upper_bracket_boundary - lower_bracket_boundary )

                            elif income < upper_bracket_boundary:
                                result += bracket_rate * ( income - lower_bracket_boundary )
                                break

                            else:
                                raise ValueError("Something went wrong...")

                except:
                    raise NameError("State not found.")

        else:
            raise NameError("Filing status '" + status + "' was not found. Only 'single' is enabled at this time.")

        return result


    def COL_adjusted_expenses(self):
        adjusted_flex_expenses = self.current_flex_expenses * ( 1 + self.COL_difference )   # COL_difference should be provided as a percent difference, e.g., -0.10 for 10% less
        result = self.fixed_expenses + adjusted_flex_expenses
        return result
    
    
    def report(self):
        print("=============================")
        print("-----------CURRENT-----------")
        print("=============================")
        print(f"Federal tax burden = ${self.current_federal_tax_burden:.2f}")
        print(f"State tax burden = ${self.current_state_tax_burden:.2f}")
        print(f"Total tax burden = ${self.current_tax_burden:.2f}")
        print(f"Tax adjusted income = ${self.current_tax_adjusted_income:.2f}")
        print(f"Expenses = ${self.current_expenses:.2f}")
        print(f"Adjusted Income Factor = {self.current_AIF:.2f}")
        print("\n")
        print("=============================")
        print("---------PROSPECTIVE---------")
        print("=============================")
        print(f"Federal tax burden = ${self.prospective_federal_tax_burden:.2f}")
        print(f"State tax burden = ${self.prospective_state_tax_burden:.2f}")
        print(f"Total tax burden = ${self.prospective_tax_burden:.2f}")
        print(f"Tax adjusted offer = ${self.prospective_tax_adjusted_income:.2f}")
        print(f"expenses = ${self.prospective_expenses:.2f}")
        print(f"Adjusted Income Factor = {self.prospective_AIF:.2f}")
        print("\n")
        print("=============================")
        print("-----------SUMMARY-----------")
        print("=============================")
        self.analyze_prospect()
    
    
    def analyze_prospect(self):
        statement1 = print(f"Current AIF = {self.current_AIF:.2f}")
        statement2 = print(f"Prospective AIF = {self.prospective_AIF:.2f}")
        line_break = print("\n")
        
        disposable_current = self.current_tax_adjusted_income - self.current_expenses
        disposable_prospective = self.prospective_tax_adjusted_income - self.prospective_expenses
        disposable_delta = disposable_prospective - disposable_current
        
        ratio = self.prospective_AIF / self.current_AIF
        
        if ratio > 1:
            statement3 = print(f"Offer has a favorable AIF that is {ratio:.2f}x larger than current AIF, indicating a positive prospect.")
        else:
            statement3 = print(f"Offer has an unfavorable AIF that is {ratio:.2f}x that of the current AIF, indicating an uninviting prospect.")
        
        if disposable_delta > 0:
            statement4 = print(f"There is a projected ${disposable_delta:.2f} increase in spending cash (${disposable_delta/12:.2f}/month).")
        elif disposable_delta == 0:
            statement4 = print(f"There is no projected change in spending cash! It's exactly the same.. spooky...")
        else:
            statement4 = print(f"There is a projected ${abs(disposable_delta):.2f} decrease in spending cash (${abs(disposable_delta)/12:.2f}/month).")
    
        return statement1, statement2, line_break, statement3, statement4

# %%
OFFER = 110000
STATE = "CT"
COL_difference = -0.28      # if new location is 10% lower COL, then make this value -0.10
                            # https://www.forbes.com/advisor/mortgages/real-estate/cost-of-living-calculator/

CURRENT_INCOME = 116500
CURRENT_STATE = "CA"
CURRENT_MONTHLY_FLEX_EXPENSES = 4650
CURRENT_FLEX_EXPENSES = 12 * CURRENT_MONTHLY_FLEX_EXPENSES
FIXED_MONTHLY_EXPENSES = 2030
FIXED_EXPENSES = 12 * FIXED_MONTHLY_EXPENSES

prospect = income_comparison(OFFER, STATE, COL_difference, 
                         CURRENT_INCOME, CURRENT_STATE,
                         FIXED_EXPENSES, CURRENT_FLEX_EXPENSES)

prospect.report()
# Out:
# =============================
# -----------CURRENT-----------
# =============================
# Federal tax burden = $20806.86
# State tax burden = $7376.78
# Total tax burden = $28183.64
# Tax adjusted income = $88316.36
# Expenses = $80160.00
# Adjusted Income Factor = 1.10
#
#
# =============================
# ---------PROSPECTIVE---------
# =============================
# Federal tax burden = $19246.86
# State tax burden = $5350.00
# Total tax burden = $24596.86
# Tax adjusted offer = $85403.14
# expenses = $64536.00
# Adjusted Income Factor = 1.32
#
#
# =============================
# -----------SUMMARY-----------
# =============================
# Current AIF = 1.10
# Prospective AIF = 1.32
#
#
# Offer has a favorable AIF that is 1.20x larger than current AIF, indicating a positive prospect.
# There is a projected $12710.78 increase in spending cash ($1059.23/month).
